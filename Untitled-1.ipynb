# %%
# !cat /etc/issue
# Out:
# Ubuntu 20.04.4 LTS \n \l

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           62Gi        23Gi       3.4Gi        99Mi        35Gi        38Gi
# Swap:            0B          0B          0B

# %%
# !df -h
# Out:
# Filesystem        Size  Used Avail Use% Mounted on
# /.workspace/mark  1.5T  126G  1.4T   9% /
# tmpfs              64M     0   64M   0% /dev
# /dev/sda1         512G   13G  500G   3% /dev/termination-log
# shm                64M     0   64M   0% /dev/shm
# tmpfs              32G     0   32G   0% /sys/fs/cgroup
# tmpfs              32G     0   32G   0% /sys/firmware
# /dev/md42          28G  171M   28G   1% /workspace
# /dev/md44         1.5T  126G  1.4T   9% /etc/hostname
# tmpfs              32G     0   32G   0% /tmp
# tmpfs              32G     0   32G   0% /proc/acpi
# tmpfs              64M     0   64M   0% /proc/keys
# tmpfs              32G     0   32G   0% /proc/scsi

# %%
# !java -version
# Out:
# Picked up JAVA_TOOL_OPTIONS:  -Xmx3435m
# openjdk version "11.0.13" 2021-10-19 LTS
# OpenJDK Runtime Environment Zulu11.52+13-CA (build 11.0.13+8-LTS)
# OpenJDK 64-Bit Server VM Zulu11.52+13-CA (build 11.0.13+8-LTS, mixed mode)

# %%
# !node --version
# Out:
# v16.15.0

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !python -V
# Out:
# Python 3.8.13

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1
#     Uninstalling pip-22.1:
#       Successfully uninstalled pip-22.1
# ...

# %%
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# astroid              2.11.5
# asttokens            2.0.5
# attrs                21.4.0
# autopep8             1.6.0
# backcall             0.2.0
# bandit               1.7.4
# beautifulsoup4       4.11.1
# bleach               5.0.0
# certifi              2022.5.18.1
# cffi                 1.15.0
# charset-normalizer   2.0.12
# commonmark           0.9.1
# cryptography         37.0.2
# debugpy              1.6.0
# decorator            5.1.1
# defusedxml           0.7.1
# dill                 0.3.4
# distlib              0.3.4
# docutils             0.18.1
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.15.3
# filelock             3.7.0
# flake8               4.0.1
# gitdb                4.0.9
# GitPython            3.1.27
# idna                 3.3
# importlib-metadata   4.11.3
# importlib-resources  5.7.1
# ...

# %%
# !apt list
